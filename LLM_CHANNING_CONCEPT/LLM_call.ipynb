# %%
import os 
from dotenv import load_dotenv,find_dotenv
from openai import OpenAI
load_dotenv(find_dotenv())
# Out:
# True

# %%
Client=OpenAI(
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1",
)

# %%
message=[{"role":"user","content":"Create sample fibonaci function in python ?"}]

# %%
response = Client.chat.completions.create(
    model="deepseek/deepseek-v4.1-flash",
    messages=message,
    max_completion_tokens=50000,
    extra_headers={
        "HTTP-Referer": "https://your-site.com",
        "X-Title": "Game"
    }
)

# %%
quention=response.choices[0].message.content

# %%
result=[{"role":"user","content":f"Optimize this function {quention}"}]

# %%
response = Client.chat.completions.create(
    model="openai/gpt-4o-mini",
    messages=result,
    max_completion_tokens=50000,
    extra_headers={
        "HTTP-Referer": "https://your-site.com",
        "X-Title": "Game"
    }
)

# %%
print(response.choices[0].message.content)
# Out:
# Your current implementation of calculating Fibonacci numbers is simple and efficient in terms of time complexity (O(n)) and space complexity (O(1)). However, if you're looking for further optimizations or variations, there are a few strategies we can consider:
#
# 1. **Memoization**: If you're going to call the Fibonacci function multiple times, storing previously computed Fibonacci numbers can save time.
#
# 2. **Matrix Exponentiation**: This method computes Fibonacci numbers in logarithmic time (O(log n)), which is much faster for large `n`.
#
# 3. **Using Binet's Formula**: This formula can calculate Fibonacci numbers directly using a closed form. However, it may have precision issues for large n due to floating-point calculations.
#
# Here’s the optimized implementation using both memoization and the efficient matrix exponentiation method:
#
# ### Using Memoization
# Here's an optimized function using memoization:
#
# ```python
# def fibonacci_memoization(n, memo={}):
#     """Return the nth Fibonacci number using memoization."""
#     if n < 0:
#         raise ValueError("n must be a non-negative integer")
#     if n in memo:
#         return memo[n]
#
#     if n == 0:
#         return 0
#     elif n == 1:
#         return 1
#
#     memo[n] = fibonacci_memoization(n - 1, memo) + fibonacci_memoization(n - 2, memo)
#     return memo[n]
#
# # Example usage
# for i in range(10):
#     print(i, fibonacci_memoization(i))
# ```
#
# ### Using Matrix Exponentiation
# Here’s an efficient implementation using matrix exponentiation:
#
# ```python
# def matrix_mult(A, B):
#     return [[A[0][0] * B[0][0] + A[0][1] * B[1][0],
#              A[0][0] * B[0][1] + A[0][1] * B[1][1]],
#             [A[1][0] * B[0][0] + A[1][1] * B[1][0],
#              A[1][0] * B[0][1] + A[1][1] * B[1][1]]]
#
# def matrix_pow(M, p):
#     result = [[1, 0], [0, 1]]  # Identity matrix
#     while p:
#         if p % 2 == 1:
#             result = matrix_mult(result, M)
#         M = matrix_mult(M, M)
#         p //= 2
#     return result
#
# def fibonacci_matrix(n):
#     """Return the nth Fibonacci number using matrix exponentiation."""
#     if n < 0:
#         raise ValueError("n must be a non-negative integer")
#     if n == 0:
#         return 0
#     elif n == 1:
#         return 1
#
#     M = [[1, 1], [1, 0]]
#     result = matrix_pow(M, n - 1)
#     return result[0][0]
#
# # Example usage
# for i in range(10):
#     print(i, fibonacci_matrix(i))
# ```
#
# ### Summary
# Both the memoization approach and matrix exponentiation are significantly faster for larger values of `n`. If you're looking for a balance between simplicity and performance, memoization is easy to implement and understand. The matrix exponentiation method is more efficient for large values of `n`.
#
# You can choose the approach that best fits your needs based on performance requirements and potential number size.
